# %% [markdown]
# # Importing pandas

# %%
import pandas as pd

# %% [markdown]
# # Loading up a csv file and assigning it to a variable named disney

# %%
disney = pd.read_csv('DisneylandRestaurants.csv')

# %% [markdown]
# # Making it possible to view every row within the data frame

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Adding new columns to the data frame

# %%
disney['Type Of Service'] = ''

# %%
disney['Established'] = ''

# %%
disney['Vegetarian Options'] = ''

# %%
disney['Breakfast Price'] = ''

# %%
disney['Lunch/Dinner Price'] = ''

# %% [markdown]
# # Reordering columns within the data frame

# %%
disney = disney[['Restaurant', 'Location', 'Theme Park', 'Breakfast Price', 'Lunch/Dinner Price', 'Vegetarian Options', 'Type Of Service', 'Established']]

# %% [markdown]
# # Inputting values into each row of new columns

# %%
disney.loc[0, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[0, 'Breakfast Price'] = '$$'
disney.loc[0, 'Lunch/Dinner Price'] = '$$'
disney.loc[0, 'Vegetarian Options'] = 'Yes'
disney.loc[0, 'Established'] = '2021'

# %%
disney.loc[1, 'Type Of Service'] = 'Quick Service'
disney.loc[1, 'Established'] = 'June 4, 2021'
disney.loc[1, 'Breakfast Price'] = '$$'
disney.loc[1, 'Lunch/Dinner Price'] = '$$'
disney.loc[1, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[2, 'Type Of Service'] = 'Snack Cart'
disney.loc[2, 'Established'] = 'June 4, 2021'
disney.loc[2, 'Breakfast Price'] = '$'
disney.loc[2, 'Lunch/Dinner Price'] = '$'
disney.loc[2, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[3, 'Type Of Service'] = 'Snack Cart'
disney.loc[3, 'Established'] = 'June 4, 2021'
disney.loc[3, 'Breakfast Price'] = '$'
disney.loc[3, 'Lunch/Dinner Price'] = '$'
disney.loc[3, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[4, 'Type Of Service'] = 'Table Service'
disney.loc[4, 'Established'] = 'June 15, 2012'
disney.loc[4, 'Breakfast Price'] = '$$$'
disney.loc[4, 'Lunch/Dinner Price'] = '$$$'
disney.loc[4, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[5, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[5, 'Established'] = 'June 15, 2012'
disney.loc[5, 'Breakfast Price'] = '$$$'
disney.loc[5, 'Lunch/Dinner Price'] = '$$$'
disney.loc[5, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[6, 'Type Of Service'] = 'Quick Service'
disney.loc[6, 'Established'] = 'June 15, 2012'
disney.loc[6, 'Breakfast Price'] = '$'
disney.loc[6, 'Lunch/Dinner Price'] = '$'
disney.loc[6, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[7, 'Type Of Service'] = 'Quick Service'
disney.loc[7, 'Established'] = 'June 15, 2012'
disney.loc[7, 'Breakfast Price'] = '$'
disney.loc[7, 'Lunch/Dinner Price'] = '$'
disney.loc[7, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[8, 'Type Of Service'] = 'Quick Service'
disney.loc[8, 'Established'] = 'June 13, 2012'
disney.loc[8, 'Breakfast Price'] = 'N/A'
disney.loc[8, 'Lunch/Dinner Price'] = '$'
disney.loc[8, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[9, 'Type Of Service'] = 'Kiosk'
disney.loc[9, 'Established'] = 'June 13, 2012'
disney.loc[9, 'Breakfast Price'] = '$'
disney.loc[9, 'Lunch/Dinner Price'] = '$'
disney.loc[9, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[10, 'Type Of Service'] = 'Quick Service'
disney.loc[10, 'Established'] = 'June 13, 2012'
disney.loc[10, 'Breakfast Price'] = 'N/A'
disney.loc[10, 'Lunch/Dinner Price'] = '$'
disney.loc[10, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[11, 'Type Of Service'] = 'Quick Service'
disney.loc[11, 'Established'] = 'March 20, 2015'
disney.loc[11, 'Breakfast Price'] = '$'
disney.loc[11, 'Lunch/Dinner Price'] = '$'
disney.loc[11, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[12, 'Type Of Service'] = 'Quick Service'
disney.loc[12, 'Established'] = 'February 8, 2001'
disney.loc[12, 'Breakfast Price'] = 'N/A'
disney.loc[12, 'Lunch/Dinner Price'] = '$'
disney.loc[12, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[13, 'Type Of Service'] = 'Kiosk'
disney.loc[13, 'Established'] = 'February 8, 2001'
disney.loc[13, 'Breakfast Price'] = '$'
disney.loc[13, 'Lunch/Dinner Price'] = '$'
disney.loc[13, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[14, 'Type Of Service'] = 'Snack Cart'
disney.loc[14, 'Established'] = 'February 8, 2001'
disney.loc[14, 'Breakfast Price'] = '$'
disney.loc[14, 'Lunch/Dinner Price'] = '$'
disney.loc[14, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[15, 'Type Of Service'] = 'Kiosk'
disney.loc[15, 'Established'] = 'February 8, 2001'
disney.loc[15, 'Breakfast Price'] = '$'
disney.loc[15, 'Lunch/Dinner Price'] = '$'
disney.loc[15, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[16, 'Type Of Service'] = 'Kiosk'
disney.loc[16, 'Established'] = 'February 8, 2001'
disney.loc[16, 'Breakfast Price'] = 'N/A'
disney.loc[16, 'Lunch/Dinner Price'] = '$'
disney.loc[16, 'Vegetarian Options'] = 'No'

# %%
disney.loc[17, 'Type Of Service'] = 'Quick Service'
disney.loc[17, 'Established'] = 'July 1, 2011'
disney.loc[17, 'Breakfast Price'] = 'N/A'
disney.loc[17, 'Lunch/Dinner Price'] = '$'
disney.loc[17, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[18, 'Type Of Service'] = 'Quick Service'
disney.loc[18, 'Established'] = 'February 8, 2001'
disney.loc[18, 'Breakfast Price'] = 'N/A'
disney.loc[18, 'Lunch/Dinner Price'] = '$'
disney.loc[18, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[19, 'Type Of Service'] = 'Kiosk'
disney.loc[19, 'Established'] = 'February 8, 2001'
disney.loc[19, 'Breakfast Price'] = '$'
disney.loc[19, 'Lunch/Dinner Price'] = '$'
disney.loc[19, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[20, 'Type Of Service'] = 'Quick Service'
disney.loc[20, 'Established'] = 'July 1, 2011'
disney.loc[20, 'Breakfast Price'] = 'N/A'
disney.loc[20, 'Lunch/Dinner Price'] = '$'
disney.loc[20, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[21, 'Type Of Service'] = 'Table Service'
disney.loc[21, 'Established'] = 'August 25, 2021'
disney.loc[21, 'Breakfast Price'] = 'N/A'
disney.loc[21, 'Lunch/Dinner Price'] = '$$'
disney.loc[21, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[22, 'Type Of Service'] = 'Quick Service'
disney.loc[22, 'Established'] = 'June 17, 2021'
disney.loc[22, 'Breakfast Price'] = '$$'
disney.loc[22, 'Lunch/Dinner Price'] = '$$'
disney.loc[22, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[23, 'Type Of Service'] = 'Quick Service'
disney.loc[23, 'Established'] = 'February 8, 2001'
disney.loc[23, 'Breakfast Price'] = '$'
disney.loc[23, 'Lunch/Dinner Price'] = '$'
disney.loc[23, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[24, 'Type Of Service'] = 'Table Service'
disney.loc[24, 'Established'] = 'February 8, 2001'
disney.loc[24, 'Breakfast Price'] = 'N/A'
disney.loc[24, 'Lunch/Dinner Price'] = '$$'
disney.loc[24, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[25, 'Type Of Service'] = 'Kiosk'
disney.loc[25, 'Established'] = 'May 1, 2018'
disney.loc[25, 'Breakfast Price'] = '$'
disney.loc[25, 'Lunch/Dinner Price'] = '$'
disney.loc[25, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[26, 'Type Of Service'] = 'Kiosk'
disney.loc[26, 'Established'] = 'June 23, 2018'
disney.loc[26, 'Breakfast Price'] = '$'
disney.loc[26, 'Lunch/Dinner Price'] = '$'
disney.loc[26, 'Vegetarian Options'] = 'No'

# %%
disney.loc[27, 'Type Of Service'] = 'Kiosk'
disney.loc[27, 'Established'] = 'June 23, 2018'
disney.loc[27, 'Breakfast Price'] = '$'
disney.loc[27, 'Lunch/Dinner Price'] = '$'
disney.loc[27, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[28, 'Type Of Service'] = 'Table Service'
disney.loc[28, 'Established'] = 'June 23, 2018'
disney.loc[28, 'Breakfast Price'] = '$$'
disney.loc[28, 'Lunch/Dinner Price'] = '$$'
disney.loc[28, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[29, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[29, 'Established'] = 'June 23, 2018'
disney.loc[29, 'Breakfast Price'] = 'N/A'
disney.loc[29, 'Lunch/Dinner Price'] = 'N/A'
disney.loc[29, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[30, 'Type Of Service'] = 'Kiosk'
disney.loc[30, 'Established'] = 'June 23, 2018'
disney.loc[30, 'Breakfast Price'] = '$'
disney.loc[30, 'Lunch/Dinner Price'] = '$'
disney.loc[30, 'Vegetarian Options'] = 'No'

# %%
disney.loc[31, 'Type Of Service'] = 'Kiosk'
disney.loc[31, 'Established'] = 'June 23, 2018'
disney.loc[31, 'Breakfast Price'] = '$'
disney.loc[31, 'Lunch/Dinner Price'] = '$'
disney.loc[31, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[32, 'Type Of Service'] = 'Quick Service'
disney.loc[32, 'Established'] = 'August 31, 2023'
disney.loc[32, 'Breakfast Price'] = 'N/A'
disney.loc[32, 'Lunch/Dinner Price'] = '$'
disney.loc[32, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[33, 'Type Of Service'] = 'Kiosk'
disney.loc[33, 'Established'] = 'February 8, 2001'
disney.loc[33, 'Breakfast Price'] = '$'
disney.loc[33, 'Lunch/Dinner Price'] = '$'
disney.loc[33, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[34, 'Type Of Service'] = 'Quick Service'
disney.loc[34, 'Established'] = 'February 8, 2001'
disney.loc[34, 'Breakfast Price'] = 'N/A'
disney.loc[34, 'Lunch/Dinner Price'] = '$'
disney.loc[34, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[35, 'Type Of Service'] = 'Quick Service'
disney.loc[35, 'Established'] = 'June 7, 2012'
disney.loc[35, 'Breakfast Price'] = '$'
disney.loc[35, 'Lunch/Dinner Price'] = '$'
disney.loc[35, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[36, 'Type Of Service'] = 'Quick Service'
disney.loc[36, 'Established'] = 'July 19, 2023'
disney.loc[36, 'Breakfast Price'] = 'N/A'
disney.loc[36, 'Lunch/Dinner Price'] = '$'
disney.loc[36, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[37, 'Type Of Service'] = 'Quick Service'
disney.loc[37, 'Established'] = 'July 26, 2023'
disney.loc[37, 'Breakfast Price'] = 'N/A'
disney.loc[37, 'Lunch/Dinner Price'] = '$'
disney.loc[37, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[38, 'Type Of Service'] = 'Kiosk'
disney.loc[38, 'Established'] = 'July 26, 2023'
disney.loc[38, 'Breakfast Price'] = '$'
disney.loc[38, 'Lunch/Dinner Price'] = '$'
disney.loc[38, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[39, 'Type Of Service'] = 'Quick Service'
disney.loc[39, 'Established'] = 'June 4, 1992'
disney.loc[39, 'Breakfast Price'] = '$'
disney.loc[39, 'Lunch/Dinner Price'] = '$'
disney.loc[39, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[40, 'Type Of Service'] = 'Kiosk'
disney.loc[40, 'Established'] = 'June 17, 2021'
disney.loc[40, 'Breakfast Price'] = '$'
disney.loc[40, 'Lunch/Dinner Price'] = '$'
disney.loc[40, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[41, 'Type Of Service'] = 'Quick Service'
disney.loc[41, 'Established'] = 'December 19, 2018'
disney.loc[41, 'Breakfast Price'] = '$'
disney.loc[41, 'Lunch/Dinner Price'] = '$'
disney.loc[41, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[42, 'Type Of Service'] = 'Quick Service'
disney.loc[42, 'Established'] = 'January 10, 1967'
disney.loc[42, 'Breakfast Price'] = '$'
disney.loc[42, 'Lunch/Dinner Price'] = '$'
disney.loc[42, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[43, 'Type Of Service'] = 'Quick Service'
disney.loc[43, 'Established'] = 'July 1, 2021'
disney.loc[43, 'Breakfast Price'] = 'N/A'
disney.loc[43, 'Lunch/Dinner Price'] = '$'
disney.loc[43, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[44, 'Type Of Service'] = 'Quick Service'
disney.loc[44, 'Established'] = 'October 25, 2024'
disney.loc[44, 'Breakfast Price'] = 'N/A'
disney.loc[44, 'Lunch/Dinner Price'] = '$$'
disney.loc[44, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[45, 'Type Of Service'] = 'Kiosk'
disney.loc[45, 'Established'] = 'September 25, 2009'
disney.loc[45, 'Breakfast Price'] = '$'
disney.loc[45, 'Lunch/Dinner Price'] = '$'
disney.loc[45, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[46, 'Type Of Service'] = 'Snack Cart'
disney.loc[46, 'Established'] = 'March 12, 2013'
disney.loc[46, 'Breakfast Price'] = '$'
disney.loc[46, 'Lunch/Dinner Price'] = '$'
disney.loc[46, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[47, 'Type Of Service'] = 'Quick Service'
disney.loc[47, 'Established'] = 'February 24, 2017'
disney.loc[47, 'Breakfast Price'] = '$'
disney.loc[47, 'Lunch/Dinner Price'] = '$'
disney.loc[47, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[48, 'Type Of Service'] = 'Kiosk'
disney.loc[48, 'Established'] = 'April 15, 1983'
disney.loc[48, 'Breakfast Price'] = '$'
disney.loc[48, 'Lunch/Dinner Price'] = '$'
disney.loc[48, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[49, 'Type Of Service'] = 'Quick Service'
disney.loc[49, 'Established'] = 'July 17, 1955'
disney.loc[49, 'Breakfast Price'] = 'N/A'
disney.loc[49, 'Lunch/Dinner Price'] = '$'
disney.loc[49, 'Vegetarian Options'] = 'No'

# %%
disney.loc[50, 'Type Of Service'] = 'Quick Service'
disney.loc[50, 'Established'] = 'February 6, 2001'
disney.loc[50, 'Breakfast Price'] = 'N/A'
disney.loc[50, 'Lunch/Dinner Price'] = '$'
disney.loc[50, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[51, 'Type Of Service'] = 'Table Service'
disney.loc[51, 'Established'] = 'August 17, 1955'
disney.loc[51, 'Breakfast Price'] = '$'
disney.loc[51, 'Lunch/Dinner Price'] = '$$$'
disney.loc[51, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[52, 'Type Of Service'] = 'Quick Service'
disney.loc[52, 'Established'] = 'September 12, 1978'
disney.loc[52, 'Breakfast Price'] = 'N/A'
disney.loc[52, 'Lunch/Dinner Price'] = '$'
disney.loc[52, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[53, 'Type Of Service'] = 'Table Service'
disney.loc[53, 'Established'] = 'July 17, 1955'
disney.loc[53, 'Breakfast Price'] = '$'
disney.loc[53, 'Lunch/Dinner Price'] = '$$'
disney.loc[53, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[54, 'Type Of Service'] = 'Quick Service'
disney.loc[54, 'Established'] = 'July 17, 1955'
disney.loc[54, 'Breakfast Price'] = 'N/A'
disney.loc[54, 'Lunch/Dinner Price'] = '$'
disney.loc[54, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[55, 'Type Of Service'] = 'Kiosk'
disney.loc[55, 'Established'] = 'November 25, 1997'
disney.loc[55, 'Breakfast Price'] = '$'
disney.loc[55, 'Lunch/Dinner Price'] = '$'
disney.loc[55, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[56, 'Type Of Service'] = 'Quick Service'
disney.loc[56, 'Established'] = 'November 25, 1997'
disney.loc[56, 'Breakfast Price'] = '$'
disney.loc[56, 'Lunch/Dinner Price'] = '$'
disney.loc[56, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[57, 'Type Of Service'] = 'Quick Service'
disney.loc[57, 'Established'] = 'July 17, 1955'
disney.loc[57, 'Breakfast Price'] = '$'
disney.loc[57, 'Lunch/Dinner Price'] = '$'
disney.loc[57, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[58, 'Type Of Service'] = 'Buffet'
disney.loc[58, 'Established'] = 'July 18, 1965'
disney.loc[58, 'Breakfast Price'] = '$$'
disney.loc[58, 'Lunch/Dinner Price'] = '$$'
disney.loc[58, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[59, 'Type Of Service'] = 'Table Service'
disney.loc[59, 'Established'] = 'March 18, 1967'
disney.loc[59, 'Breakfast Price'] = 'N/A'
disney.loc[59, 'Lunch/Dinner Price'] = '$$$'
disney.loc[59, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[60, 'Type Of Service'] = 'Table Service'
disney.loc[60, 'Established'] = 'July 24, 1966'
disney.loc[60, 'Breakfast Price'] = 'N/A'
disney.loc[60, 'Lunch/Dinner Price'] = '$$'
disney.loc[60, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[61, 'Type Of Service'] = 'Kiosk'
disney.loc[61, 'Established'] = 'July 24, 1966'
disney.loc[61, 'Breakfast Price'] = '$'
disney.loc[61, 'Lunch/Dinner Price'] = '$'
disney.loc[61, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[62, 'Type Of Service'] = 'Quick Service'
disney.loc[62, 'Established'] = 'July 17, 1955'
disney.loc[62, 'Breakfast Price'] = 'N/A'
disney.loc[62, 'Lunch/Dinner Price'] = '$'
disney.loc[62, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[63, 'Type Of Service'] = 'Quick Service'
disney.loc[63, 'Established'] = 'September 7, 2023'
disney.loc[63, 'Breakfast Price'] = 'N/A'
disney.loc[63, 'Lunch/Dinner Price'] = '$'
disney.loc[63, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[64, 'Type Of Service'] = 'Quick Service'
disney.loc[64, 'Established'] = 'May 31, 2019'
disney.loc[64, 'Breakfast Price'] = '$'
disney.loc[64, 'Lunch/Dinner Price'] = '$'
disney.loc[64, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[65, 'Type Of Service'] = 'Quick Service'
disney.loc[65, 'Established'] = 'July 15, 2021'
disney.loc[65, 'Breakfast Price'] = '$'
disney.loc[65, 'Lunch/Dinner Price'] = '$'
disney.loc[65, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[66, 'Type Of Service'] = 'Quick Service'
disney.loc[66, 'Established'] = 'May 31, 2019'
disney.loc[66, 'Breakfast Price'] = '$'
disney.loc[66, 'Lunch/Dinner Price'] = '$'
disney.loc[66, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[67, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[67, 'Established'] = '2019'
disney.loc[67, 'Breakfast Price'] = '$$'
disney.loc[67, 'Lunch/Dinner Price'] = '$$'
disney.loc[67, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[68, 'Type Of Service'] = 'Quick Service'
disney.loc[68, 'Established'] = '2019'
disney.loc[68, 'Breakfast Price'] = '$'
disney.loc[68, 'Lunch/Dinner Price'] = '$'
disney.loc[68, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[69, 'Type Of Service'] = 'Quick Service'
disney.loc[69, 'Established'] = '2018'
disney.loc[69, 'Breakfast Price'] = 'N/A'
disney.loc[69, 'Lunch/Dinner Price'] = '$$'
disney.loc[69, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[70, 'Type Of Service'] = 'Quick Service'
disney.loc[70, 'Established'] = '2001'
disney.loc[70, 'Breakfast Price'] = '$'
disney.loc[70, 'Lunch/Dinner Price'] = '$$'
disney.loc[70, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[71, 'Type Of Service'] = 'Quick Service'
disney.loc[71, 'Established'] = '2023'
disney.loc[71, 'Breakfast Price'] = '$'
disney.loc[71, 'Lunch/Dinner Price'] = '$'
disney.loc[71, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[72, 'Type Of Service'] = 'Quick Service'
disney.loc[72, 'Established'] = '2023'
disney.loc[72, 'Breakfast Price'] = '$'
disney.loc[72, 'Lunch/Dinner Price'] = '$'
disney.loc[72, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[73, 'Type Of Service'] = 'Table Service'
disney.loc[73, 'Established'] = 'TBA'
disney.loc[73, 'Breakfast Price'] = 'N/A'
disney.loc[73, 'Lunch/Dinner Price'] = '$$$'
disney.loc[73, 'Vegetarian Options'] = 'No'

# %%
disney.loc[74, 'Type Of Service'] = 'Table Service'
disney.loc[74, 'Established'] = '2019'
disney.loc[74, 'Breakfast Price'] = 'N/A'
disney.loc[74, 'Lunch/Dinner Price'] = '$$'
disney.loc[74, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[75, 'Type Of Service'] = 'Quick Service'
disney.loc[75, 'Established'] = '2023'
disney.loc[75, 'Breakfast Price'] = '$'
disney.loc[75, 'Lunch/Dinner Price'] = '$'
disney.loc[75, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[76, 'Type Of Service'] = 'Quick Service'
disney.loc[76, 'Established'] = '2019'
disney.loc[76, 'Breakfast Price'] = 'N/A'
disney.loc[76, 'Lunch/Dinner Price'] = '$$'
disney.loc[76, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[77, 'Type Of Service'] = 'Kiosk'
disney.loc[77, 'Established'] = '2024'
disney.loc[77, 'Breakfast Price'] = '$'
disney.loc[77, 'Lunch/Dinner Price'] = '$'
disney.loc[77, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[78, 'Type Of Service'] = 'Table Service'
disney.loc[78, 'Established'] = '2024'
disney.loc[78, 'Breakfast Price'] = 'N/A'
disney.loc[78, 'Lunch/Dinner Price'] = '$$'
disney.loc[78, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[79, 'Type Of Service'] = 'Quick Service'
disney.loc[79, 'Established'] = '2019'
disney.loc[79, 'Breakfast Price'] = '$'
disney.loc[79, 'Lunch/Dinner Price'] = '$'
disney.loc[79, 'Vegetarian Options'] = 'No'

# %%
disney.loc[80, 'Type Of Service'] = 'Snack Cart'
disney.loc[80, 'Established'] = '2009'
disney.loc[80, 'Breakfast Price'] = '$'
disney.loc[80, 'Lunch/Dinner Price'] = '$'
disney.loc[80, 'Vegetarian Options'] = 'No'

# %%
disney.loc[81, 'Type Of Service'] = 'Table Service'
disney.loc[81, 'Established'] = '2024'
disney.loc[81, 'Breakfast Price'] = 'N/A'
disney.loc[81, 'Lunch/Dinner Price'] = '$$$'
disney.loc[81, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[82, 'Type Of Service'] = 'Quick Service'
disney.loc[82, 'Established'] = '2012'
disney.loc[82, 'Breakfast Price'] = '$'
disney.loc[82, 'Lunch/Dinner Price'] = '$'
disney.loc[82, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[83, 'Type Of Service'] = 'Table Service'
disney.loc[83, 'Established'] = '2012'
disney.loc[83, 'Breakfast Price'] = 'N/A'
disney.loc[83, 'Lunch/Dinner Price'] = '$$'
disney.loc[83, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[84, 'Type Of Service'] = 'Quick Service'
disney.loc[84, 'Established'] = '2025'
disney.loc[84, 'Breakfast Price'] = '$'
disney.loc[84, 'Lunch/Dinner Price'] = '$'
disney.loc[84, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[85, 'Type Of Service'] = 'Quick Service'
disney.loc[85, 'Established'] = '2020'
disney.loc[85, 'Breakfast Price'] = '$'
disney.loc[85, 'Lunch/Dinner Price'] = '$'
disney.loc[85, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[86, 'Type Of Service'] = 'Table Service'
disney.loc[86, 'Established'] = '2023'
disney.loc[86, 'Breakfast Price'] = 'N/A'
disney.loc[86, 'Lunch/Dinner Price'] = '$$$'
disney.loc[86, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[87, 'Type Of Service'] = 'Quick Service'
disney.loc[87, 'Established'] = '2025'
disney.loc[87, 'Breakfast Price'] = '$'
disney.loc[87, 'Lunch/Dinner Price'] = '$'
disney.loc[87, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[88, 'Type Of Service'] = 'Table Service'
disney.loc[88, 'Established'] = '2019'
disney.loc[88, 'Breakfast Price'] = '$$'
disney.loc[88, 'Lunch/Dinner Price'] = '$$'
disney.loc[88, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[89, 'Type Of Service'] = 'Quick Service'
disney.loc[89, 'Established'] = '2019'
disney.loc[89, 'Breakfast Price'] = 'N/A'
disney.loc[89, 'Lunch/Dinner Price'] = '$'
disney.loc[89, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[90, 'Type Of Service'] = 'Table Service'
disney.loc[90, 'Established'] = '2024'
disney.loc[90, 'Breakfast Price'] = '$$'
disney.loc[90, 'Lunch/Dinner Price'] = '$$'
disney.loc[90, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[91, 'Type Of Service'] = 'Quick Service'
disney.loc[91, 'Established'] = 'TBA'
disney.loc[91, 'Breakfast Price'] = '$$'
disney.loc[91, 'Lunch/Dinner Price'] = '$$'
disney.loc[91, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[92, 'Type Of Service'] = 'Quick Service'
disney.loc[92, 'Established'] = '2018'
disney.loc[92, 'Breakfast Price'] = '$'
disney.loc[92, 'Lunch/Dinner Price'] = '$'
disney.loc[92, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[93, 'Type Of Service'] = 'Quick Service'
disney.loc[93, 'Established'] = '2025'
disney.loc[93, 'Breakfast Price'] = '$'
disney.loc[93, 'Lunch/Dinner Price'] = '$'
disney.loc[93, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[94, 'Type Of Service'] = 'Quick Service'
disney.loc[94, 'Established'] = '2025'
disney.loc[94, 'Breakfast Price'] = '$'
disney.loc[94, 'Lunch/Dinner Price'] = '$'
disney.loc[94, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[95, 'Type Of Service'] = 'Table Service'
disney.loc[95, 'Established'] = '2018'
disney.loc[95, 'Breakfast Price'] = '$$'
disney.loc[95, 'Lunch/Dinner Price'] = '$$'
disney.loc[95, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[96, 'Type Of Service'] = 'Quick Service'
disney.loc[96, 'Established'] = '2014'
disney.loc[96, 'Breakfast Price'] = '$'
disney.loc[96, 'Lunch/Dinner Price'] = '$'
disney.loc[96, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[97, 'Type Of Service'] = 'Quick Service'
disney.loc[97, 'Established'] = '2014'
disney.loc[97, 'Breakfast Price'] = '$'
disney.loc[97, 'Lunch/Dinner Price'] = '$'
disney.loc[97, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[98, 'Type Of Service'] = 'Table Service'
disney.loc[98, 'Established'] = 'TBA'
disney.loc[98, 'Breakfast Price'] = '$$'
disney.loc[98, 'Lunch/Dinner Price'] = '$$'
disney.loc[98, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[99, 'Type Of Service'] = 'Quick Service'
disney.loc[99, 'Established'] = '2014'
disney.loc[99, 'Breakfast Price'] = '$'
disney.loc[99, 'Lunch/Dinner Price'] = '$'
disney.loc[99, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[100, 'Type Of Service'] = 'Quick Service'
disney.loc[100, 'Established'] = '2024'
disney.loc[100, 'Breakfast Price'] = '$'
disney.loc[100, 'Lunch/Dinner Price'] = '$'
disney.loc[100, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[101, 'Type Of Service'] = 'Table Service'
disney.loc[101, 'Established'] = '2004'
disney.loc[101, 'Breakfast Price'] = 'N/A'
disney.loc[101, 'Lunch/Dinner Price'] = '$$'
disney.loc[101, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[102, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[102, 'Established'] = '2025'
disney.loc[102, 'Breakfast Price'] = '$$'
disney.loc[102, 'Lunch/Dinner Price'] = '$$'
disney.loc[102, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[103, 'Type Of Service'] = 'Quick Service'
disney.loc[103, 'Established'] = '2018'
disney.loc[103, 'Breakfast Price'] = '$'
disney.loc[103, 'Lunch/Dinner Price'] = '$'
disney.loc[103, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[104, 'Type Of Service'] = 'Room Service'
disney.loc[104, 'Established'] = '1955'
disney.loc[104, 'Breakfast Price'] = 'N/A'
disney.loc[104, 'Lunch/Dinner Price'] = '$$'
disney.loc[104, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[105, 'Type Of Service'] = 'Buffet'
disney.loc[105, 'Established'] = '1992'
disney.loc[105, 'Breakfast Price'] = '$$'
disney.loc[105, 'Lunch/Dinner Price'] = '$$'
disney.loc[105, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[106, 'Type Of Service'] = 'Table Service'
disney.loc[106, 'Established'] = '2006'
disney.loc[106, 'Breakfast Price'] = '$$$'
disney.loc[106, 'Lunch/Dinner Price'] = '$$$'
disney.loc[106, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[107, 'Type Of Service'] = 'Quick Service'
disney.loc[107, 'Established'] = '2019'
disney.loc[107, 'Breakfast Price'] = '$'
disney.loc[107, 'Lunch/Dinner Price'] = '$'
disney.loc[107, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[108, 'Type Of Service'] = 'Quick Service'
disney.loc[108, 'Established'] = '1955'
disney.loc[108, 'Breakfast Price'] = '$'
disney.loc[108, 'Lunch/Dinner Price'] = '$'
disney.loc[108, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[109, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[109, 'Established'] = '2025'
disney.loc[109, 'Breakfast Price'] = 'N/A'
disney.loc[109, 'Lunch/Dinner Price'] = '$'
disney.loc[109, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[110, 'Type Of Service'] = 'Table Service'
disney.loc[110, 'Established'] = '2011'
disney.loc[110, 'Breakfast Price'] = '$'
disney.loc[110, 'Lunch/Dinner Price'] = '$'
disney.loc[110, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[111, 'Type Of Service'] = 'Table Service'
disney.loc[111, 'Established'] = '2023'
disney.loc[111, 'Breakfast Price'] = '$$'
disney.loc[111, 'Lunch/Dinner Price'] = '$$'
disney.loc[111, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[112, 'Type Of Service'] = 'Quick Service'
disney.loc[112, 'Established'] = '2024'
disney.loc[112, 'Breakfast Price'] = '$'
disney.loc[112, 'Lunch/Dinner Price'] = '$'
disney.loc[112, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[113, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[113, 'Established'] = '2024'
disney.loc[113, 'Breakfast Price'] = '$'
disney.loc[113, 'Lunch/Dinner Price'] = '$'
disney.loc[113, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[114, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[114, 'Established'] = '2019'
disney.loc[114, 'Breakfast Price'] = '$$'
disney.loc[114, 'Lunch/Dinner Price'] = '$$'
disney.loc[114, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[115, 'Type Of Service'] = 'Table Service'
disney.loc[115, 'Established'] = '2019'
disney.loc[115, 'Breakfast Price'] = '$$'
disney.loc[115, 'Lunch/Dinner Price'] = '$$'
disney.loc[115, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[116, 'Type Of Service'] = 'Room Service'
disney.loc[116, 'Established'] = '2021'
disney.loc[116, 'Breakfast Price'] = '$'
disney.loc[116, 'Lunch/Dinner Price'] = '$'
disney.loc[116, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[117, 'Type Of Service'] = 'Table Service'
disney.loc[117, 'Established'] = '2019'
disney.loc[117, 'Breakfast Price'] = '$$'
disney.loc[117, 'Lunch/Dinner Price'] = '$$'
disney.loc[117, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[118, 'Type Of Service'] = 'Table Service'
disney.loc[118, 'Established'] = '2001'
disney.loc[118, 'Breakfast Price'] = 'N/A'
disney.loc[118, 'Lunch/Dinner Price'] = '$$$'
disney.loc[118, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[119, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[119, 'Established'] = '2001'
disney.loc[119, 'Breakfast Price'] = 'N/A'
disney.loc[119, 'Lunch/Dinner Price'] = '$$$'
disney.loc[119, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[120, 'Type Of Service'] = 'Buffet'
disney.loc[120, 'Established'] = '2001'
disney.loc[120, 'Breakfast Price'] = '$$'
disney.loc[120, 'Lunch/Dinner Price'] = '$$'
disney.loc[120, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[121, 'Type Of Service'] = 'Room Service'
disney.loc[121, 'Established'] = '1984'
disney.loc[121, 'Breakfast Price'] = '$'
disney.loc[121, 'Lunch/Dinner Price'] = '$'
disney.loc[121, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[122, 'Type Of Service'] = 'Buffet'
disney.loc[122, 'Established'] = '2001'
disney.loc[122, 'Breakfast Price'] = 'N/A'
disney.loc[122, 'Lunch/Dinner Price'] = '$$'
disney.loc[122, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[123, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[123, 'Established'] = '2000'
disney.loc[123, 'Breakfast Price'] = '$$'
disney.loc[123, 'Lunch/Dinner Price'] = '$$'
disney.loc[123, 'Vegetarian Options'] = 'Yes'

# %%
disney.loc[124, 'Type Of Service'] = 'Bar/Lounge'
disney.loc[124, 'Established'] = '2023'
disney.loc[124, 'Breakfast Price'] = '$$'
disney.loc[124, 'Lunch/Dinner Price'] = '$$'
disney.loc[124, 'Vegetarian Options'] = 'Yes'

# %% [markdown]
# # Printing updated dataframe

# %%
disney
# Out:
#                                        Restaurant  \
# 0                                 Pym Tasting Lab
# 1                                Pym Test Kitchen
# 2                          Shawarma PalaceUpdated
# 3                                   Terran Treats
# 4                                  Carthay Circle
# 5                           Carthay Circle Lounge
# 6             Clarabelle's Hand-Scooped Ice Cream
# 7               Fiddler, Fifer and Practical Cafe
# 8                                      Cozy Cones
# 9                             Fillmore's Taste-In
# 10                                 Flo's V-8 Cafe
# 11                             Smokejumpers Grill
# 12                                  Award Wieners
# 13                           Fairfax Market (DCA)
# 14                               Hollywood Lounge
# 15                                     Schmoozies
# 16                            Studio Catering Co.
# 17                                  Bayside Brews
# ...

# %% [markdown]
# # Exporting newly updated data frame into a csv file

# %%
disney.to_csv(r'C:\Users\enriq\OneDrive\Desktop\Desktop Projects Python\Disneyland Restaurants\Disney_cleaned.csv', index=False)
